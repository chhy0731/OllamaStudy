# %%
from langchain_ollama import OllamaLLM
llm = OllamaLLM(model="gemma3:12b")
response = llm.invoke("지구의 자전 주기는?")
print(response)
# Out:
# 지구의 자전 주기는 약 23시간 56분 4초입니다. 이를 **태양일**이라고 부릅니다.
#
# *   **태양일:** 태양이 특정 지평선 위로 다시 뜨기까지 걸리는 시간입니다.
# *   **항성일:** 멀리 있는 별들을 기준으로 지구의 회전을 측정하는 시간으로, 약 23시간 56분 4초입니다.
#
# 일상생활에서 사용하는 24시간은 **평년**을 기준으로 계산된 시간이며, 지구의 자전 주기가 조금씩 느려지기 때문에 필요에 따라 윤년을 두어 오차를 보정합니다.

# %%
response
# Out:
# '지구의 자전 주기는 약 23시간 56분 4초입니다. 이를 **태양일**이라고 부릅니다. \n\n*   **태양일:** 태양이 특정 지평선 위로 다시 뜨기까지 걸리는 시간입니다.\n*   **항성일:** 멀리 있는 별들을 기준으로 지구의 회전을 측정하는 시간으로, 약 23시간 56분 4초입니다.\n\n일상생활에서 사용하는 24시간은 **평년**을 기준으로 계산된 시간이며, 지구의 자전 주기가 조금씩 느려지기 때문에 필요에 따라 윤년을 두어 오차를 보정합니다.'

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_template(
    "You are an expert in astronomy. Answer the question:\n{input}"
)

chain = prompt | llm
response = chain.invoke("지구의 자전 주기는?")
print(response)
# Out:
# Okay, let's break down Earth's rotation period (what you're asking about when you mention "자전 주기"). Here's a comprehensive answer, as an astronomer would provide, covering different ways we measure it and why it's not quite as simple as "24 hours."
#
# **The Short Answer (What Most People Think Of):**
#
# *   **Sidereal Day: 23 hours, 56 minutes, 4.091 seconds.** This is the *fundamental* rotation period of Earth. It's the time it takes for Earth to rotate *once* relative to the distant stars.  Think of it as a very precise measurement of how long it takes a specific point on Earth to return to the same position relative to a specific star.
#
# **The Longer Answer (Explaining the Complications - and why we have a 24-hour day):**
#
# The reason we don't usually say "a day is 23 hours, 56 minutes" is because of something called *solar day*.  Here's what's going on:
#
# 1.  **Earth Orbits the Sun:**  While Earth is rotating, it's *also* orbiting the Sun. This orbital motion is what complicates things.
#
# 2.  **Solar Day vs. Sidereal Day:**
#     *   **Solar Day (The "Regular" Day):** This is the time it takes for the Sun to appear in the same position in the sky (e.g., from sunrise to sunrise). The average solar day is **24 hours**.  This is what we base our clocks and calendars on.
#     *   **Sidereal Day (The True Rotation Period):** As Earth rotates, it *also* moves in its orbit around the Sun.  Because of this orbital motion, Earth has to rotate a little bit *more* than a full 360 degrees for the Sun to reappear in the same position.  That extra bit of rotation is why a sidereal day is shorter than a solar day.
#
# 3.  **The Difference – The "Extra" Hour:**  Because of Earth’s orbit, the Sun appears to be back in the same position about 4 minutes earlier each day. Over a year, this amounts to roughly one extra hour.  That's why a solar day (24 hours) is longer than a sidereal day (23h 56m 4.091s).
#
# 4. **Mean Solar Day vs. Apparent Solar Day:**  Even "24 hours" isn't perfectly constant. The Earth’s orbit is elliptical, which means its speed varies. This means that the time between sunrises isn't *exactly* the same every day.  Therefore:
#    * **Mean Solar Day:** A calculated average of the solar day over a year.  We use this as our standard "24 hour" day.
#    * **Apparent Solar Day:** The actual time between sunrise and sunrise, which varies slightly throughout the year.
#
# **Key Takeaways and Why It Matters:**
#
# *   **Astronomers use the sidereal day:** When we're doing precise astronomical calculations (like tracking the movement of stars or planets), we use the sidereal day.
# *   **Our daily lives are based on the solar day:**  For clocks, calendars, and scheduling, we use the solar day.
# *   **The difference is important for understanding Earth's motion:** It highlights that Earth's rotation is not isolated; it’s intertwined with its orbital path around the Sun.
#
#
#
# **In simple terms:** Imagine standing on a merry-go-round that’s also moving forward in a circle. The time it takes to make a full rotation relative to the *background* is shorter than the time it takes for you to face the center of the circle again (the Sun).
#
# Do you want me to elaborate on any of these points, or perhaps discuss related concepts like the Earth’s axial tilt and its effect on seasons?

# %%
from langchain_core.output_parsers import StrOutputParser

prompt = ChatPromptTemplate.from_template(
    "You are an expert in astronomy. Answer the question:\n{input}"
)
output_parser = StrOutputParser()

chain = prompt | llm | output_parser

response = chain.invoke("지구의 자전 주기는?")
print(response)
# Out:
# Okay, let's tackle the question "What is the Earth's rotation period?" (지구의 자전 주기는?).
#
# Here's the detailed answer, incorporating nuances and clarifying different ways we measure it, as an astronomy expert would:
#
# **The Short Answer:**
#
# The Earth's rotation period, or how long it takes for the Earth to spin once on its axis, is approximately **24 hours**.  More precisely, it's **23 hours, 56 minutes, and 4.091 seconds**.
#
# **The Longer, More Detailed Explanation – Because Rotation Isn't Simple!**
#
# It's important to understand that "24 hours" is a useful approximation for everyday life, but in astronomy, things require precision. Here’s a breakdown of the complexities:
#
# 1. **Sidereal Day vs. Solar Day:** This is *crucial*. There are two different ways to define a "day," and they're slightly different:
#
#    *   **Sidereal Day (항성일):** This is the time it takes for the Earth to rotate 360 degrees *relative to the distant stars*. This is the *true* rotation period.  The value I mentioned earlier – **23 hours, 56 minutes, and 4.091 seconds** – *is* the sidereal day.  It's what astronomers use when defining a rotation.  Think of it as how long it takes for a specific star to return to the same position in the sky.
#
#    *   **Solar Day (태양일):** This is the time it takes for the Sun to appear in the same position in the sky (e.g., from noon to noon). This is the "day" we experience and use in our daily lives.  The solar day is *slightly longer* than the sidereal day because the Earth is also orbiting the Sun.  A solar day averages **24 hours**.  However, the length of a solar day varies throughout the year (more on that below).
#
# 2. **Why the Difference? The Orbiting Earth:**
#
#     *   The Earth orbits the Sun in roughly 365.25 days. As the Earth rotates, it's also moving along its orbit.  This means that after one sidereal day (a full 360-degree rotation), the Earth needs to rotate a little bit *more* to bring the Sun back to the same apparent position in the sky.
#     *   This extra rotation amounts to roughly 24 minutes per day.  That’s why a solar day (24 hours) is longer than a sidereal day (23h 56m 4.091s).
#
# 3. **Variations in Rotation – It's Not Constant!**
#
#     *   **Lunar Effects:** The gravitational pull of the Moon exerts tidal forces on the Earth, which slightly slows down the Earth's rotation.
#     *   **Internal Processes:**  Changes in the Earth's interior (mass distribution, convection in the mantle) can also subtly affect rotation.
#     *   **Atmospheric Effects:** Winds and other atmospheric phenomena can cause tiny variations.
#     *   **Earthquakes and Mass Redistribution:**  Major earthquakes can actually change the distribution of mass on Earth, leading to tiny, temporary shifts in the rotation rate. This is a complex phenomenon.
#     *   **Annual Variation:** Due to a combination of factors related to atmospheric pressure changes and the distribution of mass in the oceans and atmosphere, the length of the solar day varies by up to about 2 milliseconds throughout the year.
#
# 4.  **Leap Seconds:** Because the Earth’s rotation is gradually slowing down, astronomers occasionally add "leap seconds" to Coordinated Universal Time (UTC) to keep it synchronized with astronomical time (based on the Earth's rotation). These are rare events and are controversial.
#
# **In Conclusion:**
#
# While we generally say the Earth's rotation period is 24 hours, the more accurate sidereal rotation period is 23 hours, 56 minutes, and 4.091 seconds. The difference arises from the Earth’s orbit around the Sun, and the rotation isn’t perfectly constant due to various internal and external influences.
#
#
#
# Do you want me to elaborate on any of these points, such as the effect of the Moon or the concept of leap seconds?
